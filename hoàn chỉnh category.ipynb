# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV

# %%
df= pd.read_csv("D:/nckh/ML/cleaned_ecommerce_data.csv")
df = df.drop(['Purchase Year','Purchase Month','Churn'],axis=1)

# %%
def convert_to_snake_case(column_name):
  return column_name.lower().replace(" ", "_")
df.columns = [convert_to_snake_case(col) for col in df.columns]
df
# Out:
#         customer_id purchase_date product_category  product_price  quantity
# 0             44605      5/3/2023             Home            177         1  \
# 1             44605     5/16/2021      Electronics            174         3
# 2             44605     7/13/2020            Books            413         1
# 3             44605     1/17/2023      Electronics            396         3
# 4             44605      5/1/2021            Books            259         4
# ...             ...           ...              ...            ...       ...
# 249995        33807     1/24/2023             Home            436         1
# 249996        20455      6/4/2021      Electronics            233         1
# 249997        28055    11/10/2022      Electronics            441         5
# 249998        15023     6/27/2021      Electronics             44         2
# 249999         4148      9/7/2020             Home            307         5
#
#         total_purchase_amount  customer_age  gender
# 0                         177            31  Female
# 1                         522            31  Female
# 2                         413            31  Female
# 3                        1188            31  Female
# 4                        1036            31  Female
# ...                       ...           ...     ...
# 249995                    436            63    Male
# 249996                    233            66  Female
# 249997                   2205            63  Female
# 249998                     88            64    Male
# 249999                   1535            32    Male
#
# [250000 rows x 8 columns]

# %%
product_dummies = pd.get_dummies(df['product_category'])
gender_dummies = pd.get_dummies(df['gender'])

df = df.join(product_dummies).join(gender_dummies)
df
# Out:
#         customer_id purchase_date product_category  product_price  quantity
# 0             44605      5/3/2023             Home            177         1  \
# 1             44605     5/16/2021      Electronics            174         3
# 2             44605     7/13/2020            Books            413         1
# 3             44605     1/17/2023      Electronics            396         3
# 4             44605      5/1/2021            Books            259         4
# ...             ...           ...              ...            ...       ...
# 249995        33807     1/24/2023             Home            436         1
# 249996        20455      6/4/2021      Electronics            233         1
# 249997        28055    11/10/2022      Electronics            441         5
# 249998        15023     6/27/2021      Electronics             44         2
# 249999         4148      9/7/2020             Home            307         5
#
#         total_purchase_amount  customer_age  gender  Books  Clothing
# 0                         177            31  Female  False     False  \
# 1                         522            31  Female  False     False
# 2                         413            31  Female   True     False
# 3                        1188            31  Female  False     False
# 4                        1036            31  Female   True     False
# ...                       ...           ...     ...    ...       ...
# 249995                    436            63    Male  False     False
# 249996                    233            66  Female  False     False
# 249997                   2205            63  Female  False     False
# 249998                     88            64    Male  False     False
# 249999                   1535            32    Male  False     False
#
#         Electronics   Home  Female   Male
# 0             False   True    True  False
# 1              True  False    True  False
# 2             False  False    True  False
# 3              True  False    True  False
# 4             False  False    True  False
# ...             ...    ...     ...    ...
# 249995        False   True   False   True
# 249996         True  False    True  False
# 249997         True  False    True  False
# 249998         True  False   False   True
# 249999        False   True   False   True
#
# [250000 rows x 14 columns]

# %%
def convert_to_snake_case(column_name):
  return column_name.lower().replace(" ", "_")
df.columns = [convert_to_snake_case(col) for col in df.columns]
df
# Out:
#         customer_id purchase_date product_category  product_price  quantity
# 0             44605      5/3/2023             Home            177         1  \
# 1             44605     5/16/2021      Electronics            174         3
# 2             44605     7/13/2020            Books            413         1
# 3             44605     1/17/2023      Electronics            396         3
# 4             44605      5/1/2021            Books            259         4
# ...             ...           ...              ...            ...       ...
# 249995        33807     1/24/2023             Home            436         1
# 249996        20455      6/4/2021      Electronics            233         1
# 249997        28055    11/10/2022      Electronics            441         5
# 249998        15023     6/27/2021      Electronics             44         2
# 249999         4148      9/7/2020             Home            307         5
#
#         total_purchase_amount  customer_age  gender  books  clothing
# 0                         177            31  Female  False     False  \
# 1                         522            31  Female  False     False
# 2                         413            31  Female   True     False
# 3                        1188            31  Female  False     False
# 4                        1036            31  Female   True     False
# ...                       ...           ...     ...    ...       ...
# 249995                    436            63    Male  False     False
# 249996                    233            66  Female  False     False
# 249997                   2205            63  Female  False     False
# 249998                     88            64    Male  False     False
# 249999                   1535            32    Male  False     False
#
#         electronics   home  female   male
# 0             False   True    True  False
# 1              True  False    True  False
# 2             False  False    True  False
# 3              True  False    True  False
# 4             False  False    True  False
# ...             ...    ...     ...    ...
# 249995        False   True   False   True
# 249996         True  False    True  False
# 249997         True  False    True  False
# 249998         True  False   False   True
# 249999        False   True   False   True
#
# [250000 rows x 14 columns]
